# %% [markdown]
# # Project Data engineering 2023-2024
# ### Bers Goudantov, 2ITAI

# %% [markdown]
# ## Data Cleaning

# %%
# requirements install
# !pip install pandera
# !pip install boto3
# !pip install pandasql
# !pip install numpy
# !pip install awswrangler
# !pip install awscli
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 6.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 10.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.5 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 2.6 MB/s eta 0:00:00
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.3 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 43.5 MB/s eta 0:00:00:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 2.4 MB/s eta 0:00:00
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
## data laden
import os
import pandas as pd

# Define the ROOT directory
ROOT = "source_data"

# Define instance root
instance_root = os.path.abspath(ROOT)

# Generate load_from_file function
def load_from_file(path, params):
    """
    Load data from a file with specified parameters.
    
    Parameters:
        path (str): The file path.
        params (dict): Parameters for loading the file (e.g., delimiter, encoding).
    Returns:
        DataFrame: The loaded data.
    """
    import pandas as pd
    
    # Load data from file
    if 'delimiter' in params:
        delimiter = params['delimiter']
        if 'encoding' in params:
            encoding = params['encoding']
            df = pd.read_csv(path, delimiter=delimiter, encoding=encoding)
        else:
            df = pd.read_csv(path, delimiter=delimiter)
    elif 'encoding' in params:
        encoding = params['encoding']
        df = pd.read_csv(path, encoding=encoding)
    else:
        df = pd.read_csv(path)
    
    return df

parameters_data_loading = {
    "path": [
        f"{ROOT}/export_aankomst.txt",
        f"{ROOT}/export_banen.csv",
        f"{ROOT}/export_klant.csv",
        f"{ROOT}/export_luchthavens.txt",
        f"{ROOT}/export_maatschappijen.txt",
        f"{ROOT}/export_planning.txt",
        f"{ROOT}/export_vetrek.txt",
        f"{ROOT}/export_vliegtuig.txt",
        f"{ROOT}/export_vliegtuigtype.csv",
        f"{ROOT}/export_vlucht.txt",
        f"{ROOT}/export_weer.txt",
    ],
    "params": [
        {'delimiter': '\t'},
        {'delimiter': ';'},
        {'delimiter': ';'},
        {'encoding': 'windows-1252', 'delimiter': '\t'},
        {'encoding': 'windows-1252', 'delimiter': '\t'},
        {'delimiter': '\t'},
        {'delimiter': '\t'},
        {'delimiter': '\t'},
        {'delimiter': ';'},
        {'delimiter': '\t'},
        {'delimiter': '\t'}
    ]
}

for path, params in zip(parameters_data_loading['path'], parameters_data_loading['params']):
    load_from_file(path=path, params=params)
# Out:
# /tmp/ipykernel_11271/873540706.py:31: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, delimiter=delimiter)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 70
#      40 parameters_data_loading = {
#      41     "path": [
#      42         f"{ROOT}/export_aankomst.txt",
#    (...)
#      66     ]
#      67 }
#      69 for path, params in zip(parameters_data_loading['path'], parameters_data_loading['params']):
# ---> 70     load_from_file(path=path, params=params)
#
# Cell In[8], line 31, in load_from_file(path, params)
#      29         df = pd.read_csv(path, delimiter=delimiter, encoding=encoding)
#      30     else:
# ---> 31         df = pd.read_csv(path, delimiter=delimiter)
#      32 elif 'encoding' in params:
#      33     encoding = params['encoding']
#
# ...
